# %%
from data_pipeline.open_data_raw_material_price.core import OpenDataRawMaterialPrice
from data_pipeline.open_data_marine_weather.core import OpenDataMarineWeather
from data_pipeline.open_data_terrestrial_weather.core import OpenDataTerrestrialWeather
import pandas as pd
import functools
from sklearn.preprocessing import QuantileTransformer, PowerTransformer ,MinMaxScaler, StandardScaler, RobustScaler, MaxAbsScaler, Normalizer
import numpy as np
from sklearn.linear_model import ElasticNet
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import make_scorer, mean_squared_error

from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.model_selection import TimeSeriesSplit

# transformer
def log_transform(df):
    return np.log1p(df)

def sqrt_transform(df):
    return np.sqrt(df)



log = log_transform
sqrt = sqrt_transform
min_max = MinMaxScaler()
standard = StandardScaler()
robust = RobustScaler()
max_abs = MaxAbsScaler()
normal = Normalizer()
quantile = QuantileTransformer()
box_cox = PowerTransformer(method='box-cox')
yeo_johnson = PowerTransformer(method='yeo-johnson')

t_names = ['log', 'sqrt', 'min_max', 'standard', 'robust', 'max_abs', 'quantile', 'yeo_johnson', 'None']
transformers = [log, sqrt, min_max, standard, robust, max_abs, quantile, yeo_johnson, 'None']

# %%
def sum_corr(df):
    # default: method=pearson, min_periods=1
    # method{‘pearson’, ‘kendall’, ‘spearman’} 
    corr = df.corr()
    return abs(corr['당일조사가격'].drop('당일조사가격')).sum()

def analyze_skew(df):
    return get_skews(df)

def analyze_coef(df):
    return sum_coef(df)

def transform(transformer, df):
    if isinstance(transformer, TransformerMixin):
        return pd.DataFrame(transformer.fit_transform(df), columns=df.columns)
    elif transformer == 'None':
        return df
    else: 
        return transformer(df)


def build_dataset(date="201908"):
    t = OpenDataTerrestrialWeather(
        date=date
    )
    t_df = t.clean(t.filter(t.input_df))

    m = OpenDataMarineWeather(
        date=date
    )
    m_df = m.clean(m.filter(m.input_df))

    p = OpenDataRawMaterialPrice(
        date=date
    )
    p_df = p.clean(p.filter(p.input_df))
    print(p_df)


    w_df = pd.merge(
                t_df, m_df,
                how='inner', on="일시"
            )
    
    origin_df = pd.merge(
                    p_df, w_df, how="inner", left_on="조사일자", right_on="일시"
                ).drop("일시", axis=1).astype(dtype={"조사일자": "datetime64"})

    return origin_df

def split_xy(df):
    X = df.drop("당일조사가격" ,axis=1)
    y = df['당일조사가격'].rename('price')
    return X, y

def corr_xy(x, y):
    corr = pd.concat([x,y] ,axis=1).corr()
    return abs(corr['price']).drop('price').sum()

def search_transformers(column, X: pd.DataFrame, y: pd.Series):
    """
        iterate transformer for X and compare with y (corr_xy)
    """
    x = X[column]
    l_tx = list(map(functools.partial(transform, df=pd.DataFrame(x)), transformers))

    l_coef = list(map(functools.partial(corr_xy, y=y), l_tx))
 
    # find max coef and index 
    max_coef = max(l_coef)
    max_index = l_coef.index(max_coef)
    transformed_column = l_tx[max_index]
    
    # proper_transformer = t_names[max_index]
    return transformed_column
                
def iterate_x(y: pd.Series, X: pd.DataFrame):
    # iterate X
    return pd.concat([pd.concat(list(map(functools.partial(search_transformers, X=X, y=y), X.columns.tolist())), axis=1), y], axis=1)

def grid_search(X: pd.DataFrame, y: pd.Series):
    """
    return: result grid, pd DataFrame
    """
    l_ty = list(map(functools.partial(transform, df=pd.DataFrame(y)), transformers))
    
    # iterate y
    result = list(map(functools.partial(iterate_x, X=X), l_ty))
    #print(result)
    return result


def customized_rmse(y, y_pred):
    error = y - y_pred
    def penalize(x):
        if x > 0:
            # if y > y_pred, penalize 10%
            return x * 1.1
        else:
            return x
    X = np.vectorize(penalize)(error)
    return np.sqrt(np.square(X).mean())

def set_train_test(df:pd.DataFrame):
    """
        TODO: search grid to find proper train test volume
    :param df: dataset
    :return: train Xy, test Xy
    """
    predict_days = 7
    # TODO: it should be processed in data_pipeline
    reversed_time = df["조사일자"].drop_duplicates().sort_values(ascending=False).tolist()
    standard_date = reversed_time[predict_days]

    train = df[df.조사일자.dt.date < standard_date]
    test = df[df.조사일자.dt.date >= standard_date]
    return train, test



def f(df:pd.DataFrame):
    X = df.drop(columns =["price","조사일자"])
    y = df['price']
    return X, y

def inverser_transform(step, x, transformer):
    """
            log = log_transform
            sqrt = sqrt_transform
            min_max = MinMaxScaler()
            standard = StandardScaler()
            robust = RobustScaler()
            max_abs = MaxAbsScaler()
            normal = Normalizer()
            quantile = QuantileTransformer()
            box_cox = PowerTransformer(method='box-cox')
            yeo_johnson = PowerTransformer(method='yeo-johnson')
    
    """
#     inverse_log(Y) = np.e**Y
#     inverse_sqrt(x) = ""
#     inverse_min_max(x) = min_max.inverse_transform
    if step == 'log':
        return np.expm1(x)
    elif step == 'sqrt':
        return x**2
    else:
        transformer.inverse_transform(x)

    
def grid_search_matrix(df:pd.DataFrame, c, t_name, transformer):
    """
    params: df(already gridsearched df about tansfomer)
    return: score(rmse)
    """


    print(pd.concat([c,df], axis=1))
    train, test = set_train_test(pd.concat([c,df], axis=1))
    train_X, train_y = f(train)
    test_X, test_y = f(test)
    enet = ElasticNet()
    tscv = TimeSeriesSplit(n_splits=2)
    parametersGrid = {"max_iter": [1, 5, 10],
                      "alpha": [0.0001, 0.001, 0.01, 0.1, 1, 10, 100],
                      "l1_ratio": np.arange(0.0, 1.0, 0.1)}
    
    grid = GridSearchCV(enet, parametersGrid, scoring=make_scorer(customized_rmse, greater_is_better=False), cv=tscv.split(train_X)  )
    grid.fit(train_X,train_y)
    
    pred_y = grid.predict(test_X)
    
    r_test = inverser_transform(t_name, test_y.to_numpy().reshape(-1,1), transformer)
    r_pred = inverser_transform(t_name, pred_y.reshape(-1,1), transformer)
    return customized_rmse(r_test, r_pred)
    

def get_final_df(df):
    sum_df = pd.DataFrame(np.array(df.values.tolist())[:, :, 1], df.index, df.columns).astype("float").sum(axis=1).rename("sum")
    transformer_df = pd.DataFrame(np.array(df.values.tolist())[:, :, 0], df.index, df.columns)
    return pd.concat([sum_df, transformer_df], axis=1)


# main: pipeline
def pipeline(date="201908"):
    origin_df = build_dataset(date=date)
    numeric_df = origin_df.select_dtypes(exclude=['object', 'datetime64[ns]'])
    X, y = split_xy(numeric_df)
    return grid_search(X, y), origin_df['조사일자']
    
   # rmse = grid_search_matrix()
    
    # return get_final_df(result_df),sum_corr(numeric_df), rmse

# %%
result, date_series = pipeline("201908")

# %%
result[1]
# Out:
#        평균기온(°C)  최저기온(°C)  최고기온(°C)  최대 풍속(m/s)  평균 풍속(m/s)_x  최소 상대습도(pct)  \
# 0      3.368964  1.078399  3.517529    0.548048      0.704989      0.405388
# 1      3.368964  1.078399  3.517529    0.548048      0.704989      0.405388
# 2      3.368964  1.078399  3.517529    0.548048      0.704989      0.405388
# 3      3.368964  1.078399  3.517529    0.548048      0.704989      0.405388
# 4      3.368964  1.078399  3.517529    0.548048      0.704989      0.405388
# ...         ...       ...       ...         ...           ...           ...
# 40507  3.163273 -1.671776  3.365129    0.881882      0.811321      0.000000
# 40508  3.163273 -1.671776  3.365129    0.881882      0.811321      0.000000
# 40509  3.163273 -1.671776  3.365129    0.881882      0.811321      0.000000
# 40510  3.163273 -1.671776  3.365129    0.881882      0.811321      0.000000
# 40511  3.163273 -1.671776  3.365129    0.881882      0.811321      0.000000
#
#        평균 상대습도(pct)_x  강수 계속시간(hr)  일강수량(mm)  평균 풍속(m/s)_y  ...  \
# 0            0.876138     0.549556  0.518922      1.534968  ...
# 1            0.876138     0.549556  0.518922      1.534968  ...
# 2            0.876138     0.549556  0.518922      1.534968  ...
# 3            0.876138     0.549556  0.518922      1.534968  ...
# 4            0.876138     0.549556  0.518922      1.534968  ...
# ...               ...          ...       ...           ...  ...
# 40507        0.816002    -1.290556 -0.894013      1.846136  ...
# 40508        0.816002    -1.290556 -0.894013      1.846136  ...
# 40509        0.816002    -1.290556 -0.894013      1.846136  ...
# 40510        0.816002    -1.290556 -0.894013      1.846136  ...
# 40511        0.816002    -1.290556 -0.894013      1.846136  ...
#
#        평균 상대습도(pct)_y  평균 기온(°C)  평균 수온(°C)  평균 최대 파고(m)  평균 유의 파고(m)  \
# 0            4.522468   0.259760   3.247635     0.168669     0.168669
# 1            4.522468   0.259760   3.247635     0.168669     0.168669
# 2            4.522468   0.259760   3.247635     0.168669     0.168669
# 3            4.522468   0.259760   3.247635     0.168669     0.168669
# 4            4.522468   0.259760   3.247635     0.168669     0.168669
# ...               ...        ...        ...          ...          ...
# 40507        4.285613   0.165165   3.268380     0.452452     0.501001
# 40508        4.285613   0.165165   3.268380     0.452452     0.501001
# 40509        4.285613   0.165165   3.268380     0.452452     0.501001
# 40510        4.285613   0.165165   3.268380     0.452452     0.501001
# 40511        4.285613   0.165165   3.268380     0.452452     0.501001
#
#        최고 유의 파고(m)  최고 최대 파고(m)  평균 파주기(sec)  최고 파주기(sec)      price
# 0         0.120621     0.120621     0.000000    -2.264291  15.427249
# 1         0.120621     0.120621     0.000000    -2.264291  38.078866
# 2         0.120621     0.120621     0.000000    -2.264291  31.464265
# 3         0.120621     0.120621     0.000000    -2.264291  32.403703
# 4         0.120621     0.120621     0.000000    -2.264291  25.884358
# ...            ...          ...          ...          ...        ...
# 40507     0.382382     0.358358     0.073857    -0.745060  39.572718
# 40508     0.382382     0.358358     0.073857    -0.745060  34.146742
# 40509     0.382382     0.358358     0.073857    -0.745060  26.720778
# 40510     0.382382     0.358358     0.073857    -0.745060  32.526912
# 40511     0.382382     0.358358     0.073857    -0.745060  44.907312
#
# [40512 rows x 21 columns]

# %%
idx = 0
for X in result:
    t_name = t_names[idx]
    grid_search_matrix(X, c=date_series, t_name=t_name, transformer = transformers[idx])
    idx += 1
# Out:
#             조사일자  평균기온(°C)  최저기온(°C)  최고기온(°C)  최대 풍속(m/s)  평균 풍속(m/s)_x  \
# 0     2019-08-01  0.736236  0.881381  0.736236    0.548048      0.479174
# 1     2019-08-01  0.736236  0.881381  0.736236    0.548048      0.479174
# 2     2019-08-01  0.736236  0.881381  0.736236    0.548048      0.479174
# 3     2019-08-01  0.736236  0.881381  0.736236    0.548048      0.479174
# 4     2019-08-01  0.736236  0.881381  0.736236    0.548048      0.479174
# ...          ...       ...       ...       ...         ...           ...
# 40507 2019-08-30  0.070070  0.000000  0.165165    0.881882      1.047222
# 40508 2019-08-30  0.070070  0.000000  0.165165    0.881882      1.047222
# 40509 2019-08-30  0.070070  0.000000  0.165165    0.881882      1.047222
# 40510 2019-08-30  0.070070  0.000000  0.165165    0.881882      1.047222
# 40511 2019-08-30  0.070070  0.000000  0.165165    0.881882      1.047222
#
#        최소 상대습도(pct)  평균 상대습도(pct)_x  강수 계속시간(hr)  일강수량(mm)  ...  \
# 0          0.549049        0.326829     0.549556  0.737237  ...
# 1          0.549049        0.326829     0.549556  0.737237  ...
# 2          0.549049        0.326829     0.549556  0.737237  ...
# 3          0.549049        0.326829     0.549556  0.737237  ...
# 4          0.549049        0.326829     0.549556  0.737237  ...
# ...             ...             ...          ...       ...  ...
# 40507      0.000000        0.000000    -1.290556  0.119119  ...
# 40508      0.000000        0.000000    -1.290556  0.119119  ...
# 40509      0.000000        0.000000    -1.290556  0.119119  ...
# 40510      0.000000        0.000000    -1.290556  0.119119  ...
# 40511      0.000000        0.000000    -1.290556  0.119119  ...
#
#        평균 상대습도(pct)_y  평균 기온(°C)  평균 수온(°C)  평균 최대 파고(m)  평균 유의 파고(m)  \
# 0                 1.0   0.259760   3.247635     0.168669     0.168669
# 1                 1.0   0.259760   3.247635     0.168669     0.168669
# 2                 1.0   0.259760   3.247635     0.168669     0.168669
# 3                 1.0   0.259760   3.247635     0.168669     0.168669
# 4                 1.0   0.259760   3.247635     0.168669     0.168669
# ...               ...        ...        ...          ...          ...
# 40507             0.0   0.165165   3.268380     0.452452     0.501001
# 40508             0.0   0.165165   3.268380     0.452452     0.501001
# 40509             0.0   0.165165   3.268380     0.452452     0.501001
# 40510             0.0   0.165165   3.268380     0.452452     0.501001
# 40511             0.0   0.165165   3.268380     0.452452     0.501001
#
#        최고 유의 파고(m)  최고 최대 파고(m)  평균 파주기(sec)  최고 파주기(sec)     price
# 0         0.120621     0.120621    -1.724087    -2.264291  5.476464
# 1         0.120621     0.120621    -1.724087    -2.264291  7.280008
# 2         0.120621     0.120621    -1.724087    -2.264291  6.898715
# 3         0.120621     0.120621    -1.724087    -2.264291  6.957497
# 4         0.120621     0.120621    -1.724087    -2.264291  6.508769
# ...            ...          ...          ...          ...       ...
# 40507     0.382382     0.358358    -1.224869    -0.745060  7.356918
# 40508     0.382382     0.358358    -1.224869    -0.745060  7.062192
# 40509     0.382382     0.358358    -1.224869    -0.745060  6.572283
# 40510     0.382382     0.358358    -1.224869    -0.745060  6.965080
# 40511     0.382382     0.358358    -1.224869    -0.745060  7.609697
#
# [40512 rows x 22 columns]
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4501.25732421875, tolerance: 0.9003505706787109
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8929.9599609375, tolerance: 1.78622305393219
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4501.2236328125, tolerance: 0.9003505706787109
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8929.6396484375, tolerance: 1.78622305393219
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4501.22412109375, tolerance: 0.9003505706787109
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8929.6103515625, tolerance: 1.78622305393219
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4343.3896484375, tolerance: 0.9003505706787109
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8883.4365234375, tolerance: 1.78622305393219
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1796.1961669921875, tolerance: 0.9003505706787109
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8330.822265625, tolerance: 1.78622305393219
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1232.5645751953125, tolerance: 0.9003505706787109
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 7477.685546875, tolerance: 1.78622305393219
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4197.90625, tolerance: 0.9003505706787109
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8841.5244140625, tolerance: 1.78622305393219
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1247.1182861328125, tolerance: 0.9003505706787109
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 7881.6025390625, tolerance: 1.78622305393219
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2555.725830078125, tolerance: 0.9003505706787109
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5850.68994140625, tolerance: 1.78622305393219
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4063.486572265625, tolerance: 0.9003505706787109
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8799.3095703125, tolerance: 1.78622305393219
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1898.0306396484375, tolerance: 0.9003505706787109
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 7524.31884765625, tolerance: 1.78622305393219
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2473.063232421875, tolerance: 0.9003505706787109
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4328.72705078125, tolerance: 1.78622305393219
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3938.997314453125, tolerance: 0.9003505706787109
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8758.279296875, tolerance: 1.78622305393219
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2325.920654296875, tolerance: 0.9003505706787109
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 7321.333984375, tolerance: 1.78622305393219
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2475.97607421875, tolerance: 0.9003505706787109
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3244.85302734375, tolerance: 1.78622305393219
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3823.399658203125, tolerance: 0.9003505706787109
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8718.3505859375, tolerance: 1.78622305393219
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2357.776611328125, tolerance: 0.9003505706787109
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 7148.2880859375, tolerance: 1.78622305393219
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1872.1923828125, tolerance: 0.9003505706787109
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4102.65380859375, tolerance: 1.78622305393219
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3715.530517578125, tolerance: 0.9003505706787109
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8678.93359375, tolerance: 1.78622305393219
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2335.250732421875, tolerance: 0.9003505706787109
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6971.8779296875, tolerance: 1.78622305393219
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1760.2261962890625, tolerance: 0.9003505706787109
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4231.4326171875, tolerance: 1.78622305393219
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3610.605712890625, tolerance: 0.9003505706787109
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8640.3740234375, tolerance: 1.78622305393219
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2198.185302734375, tolerance: 0.9003505706787109
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6835.21142578125, tolerance: 1.78622305393219
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1553.940185546875, tolerance: 0.9003505706787109
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2697.76904296875, tolerance: 1.78622305393219
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3502.64599609375, tolerance: 0.9003505706787109
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8602.66796875, tolerance: 1.78622305393219
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1960.9576416015625, tolerance: 0.9003505706787109
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6674.06689453125, tolerance: 1.78622305393219
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2587.9716796875, tolerance: 0.9003505706787109
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3050.050537109375, tolerance: 1.78622305393219
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3402.04931640625, tolerance: 0.9003505706787109
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8565.8759765625, tolerance: 1.78622305393219
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1359.122802734375, tolerance: 0.9003505706787109
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6479.88330078125, tolerance: 1.78622305393219
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2381.313720703125, tolerance: 0.9003505706787109
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3448.497314453125, tolerance: 1.78622305393219
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4501.2783203125, tolerance: 0.9003505706787109
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8929.9736328125, tolerance: 1.78622305393219
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4501.234375, tolerance: 0.9003505706787109
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8929.6591796875, tolerance: 1.78622305393219
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4501.2294921875, tolerance: 0.9003505706787109
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8929.6318359375, tolerance: 1.78622305393219
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3456.443115234375, tolerance: 0.9003505706787109
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8531.1328125, tolerance: 1.78622305393219
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1494.6600341796875, tolerance: 0.9003505706787109
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3705.801513671875, tolerance: 1.78622305393219
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2307.145751953125, tolerance: 0.9003505706787109
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4864.98583984375, tolerance: 1.78622305393219
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3133.119873046875, tolerance: 0.9003505706787109
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8211.72265625, tolerance: 1.78622305393219
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2084.056396484375, tolerance: 0.9003505706787109
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3174.308349609375, tolerance: 1.78622305393219
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1622.4127197265625, tolerance: 0.9003505706787109
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1897.4317626953125, tolerance: 1.78622305393219
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2452.78173828125, tolerance: 0.9003505706787109
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 7951.74365234375, tolerance: 1.78622305393219
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1553.1300048828125, tolerance: 0.9003505706787109
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3149.23095703125, tolerance: 1.78622305393219
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1316.5986328125, tolerance: 0.9003505706787109
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 132.5579071044922, tolerance: 1.78622305393219
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2049.887451171875, tolerance: 0.9003505706787109
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 7736.2705078125, tolerance: 1.78622305393219
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1343.649169921875, tolerance: 0.9003505706787109
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 991.0509033203125, tolerance: 1.78622305393219
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1149.68701171875, tolerance: 0.9003505706787109
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1611.7578125, tolerance: 0.9003505706787109
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 7501.5576171875, tolerance: 1.78622305393219
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1251.4671630859375, tolerance: 0.9003505706787109
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 70.94025421142578, tolerance: 1.78622305393219
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 399.75531005859375, tolerance: 0.9003505706787109
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 745.5744018554688, tolerance: 0.9003505706787109
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 7187.595703125, tolerance: 1.78622305393219
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1193.949951171875, tolerance: 0.9003505706787109
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 63.35816955566406, tolerance: 1.78622305393219
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 281.8836364746094, tolerance: 0.9003505706787109
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 156.01637268066406, tolerance: 0.9003505706787109
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6848.62646484375, tolerance: 1.78622305393219
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1127.189208984375, tolerance: 0.9003505706787109
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 206.93043518066406, tolerance: 0.9003505706787109
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 19.246753692626953, tolerance: 0.9003505706787109
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6493.65771484375, tolerance: 1.78622305393219
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1078.0411376953125, tolerance: 0.9003505706787109
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 154.0890350341797, tolerance: 0.9003505706787109
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6121.9130859375, tolerance: 1.78622305393219
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 677.7246704101562, tolerance: 0.9003505706787109
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 116.34383392333984, tolerance: 0.9003505706787109
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4501.37890625, tolerance: 0.9003505706787109
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8930.04296875, tolerance: 1.78622305393219
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4501.24267578125, tolerance: 0.9003505706787109
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8929.740234375, tolerance: 1.78622305393219
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4501.23486328125, tolerance: 0.9003505706787109
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8929.7080078125, tolerance: 1.78622305393219
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5.362462520599365, tolerance: 0.9003505706787109
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5512.1953125, tolerance: 1.78622305393219
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 287.8291015625, tolerance: 0.9003505706787109
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 62.62067413330078, tolerance: 0.9003505706787109
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1830.163818359375, tolerance: 1.78622305393219
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 53.47126007080078, tolerance: 0.9003505706787109
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 41.95100021362305, tolerance: 0.9003505706787109
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 22.660259246826172, tolerance: 0.9003505706787109
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4501.4443359375, tolerance: 0.9003505706787109
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8930.2548828125, tolerance: 1.78622305393219
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4501.28076171875, tolerance: 0.9003505706787109
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8929.86328125, tolerance: 1.78622305393219
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4501.27587890625, tolerance: 0.9003505706787109
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8929.83203125, tolerance: 1.78622305393219
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4501.50927734375, tolerance: 0.9003505706787109
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8930.345703125, tolerance: 1.78622305393219
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4501.48974609375, tolerance: 0.9003505706787109
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8930.18359375, tolerance: 1.78622305393219
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4501.48974609375, tolerance: 0.9003505706787109
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8930.18359375, tolerance: 1.78622305393219
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4501.70458984375, tolerance: 0.9003505706787109
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8930.8408203125, tolerance: 1.78622305393219
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4501.705078125, tolerance: 0.9003505706787109
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8930.8388671875, tolerance: 1.78622305393219
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4501.705078125, tolerance: 0.9003505706787109
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8930.8388671875, tolerance: 1.78622305393219
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4501.748046875, tolerance: 0.9003505706787109
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8931.0810546875, tolerance: 1.78622305393219
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4501.748046875, tolerance: 0.9003505706787109
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8931.080078125, tolerance: 1.78622305393219
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4501.748046875, tolerance: 0.9003505706787109
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8931.080078125, tolerance: 1.78622305393219
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 13306.90625, tolerance: 2.6616017818450928
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1969814.25, tolerance: 393.99530029296875
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3931558.0, tolerance: 786.3709106445312
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1969791.0, tolerance: 393.99530029296875
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3931456.0, tolerance: 786.3709106445312
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1969788.25, tolerance: 393.99530029296875
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3931445.0, tolerance: 786.3709106445312
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1965436.25, tolerance: 393.99530029296875
#   positive)
#             조사일자  평균기온(°C)  최저기온(°C)  최고기온(°C)  최대 풍속(m/s)  평균 풍속(m/s)_x  \
# 0     2019-08-01  3.368964  1.078399  3.517529    0.548048      0.704989
# 1     2019-08-01  3.368964  1.078399  3.517529    0.548048      0.704989
# 2     2019-08-01  3.368964  1.078399  3.517529    0.548048      0.704989
# 3     2019-08-01  3.368964  1.078399  3.517529    0.548048      0.704989
# 4     2019-08-01  3.368964  1.078399  3.517529    0.548048      0.704989
# ...          ...       ...       ...       ...         ...           ...
# 40507 2019-08-30  3.163273 -1.671776  3.365129    0.881882      0.811321
# 40508 2019-08-30  3.163273 -1.671776  3.365129    0.881882      0.811321
# 40509 2019-08-30  3.163273 -1.671776  3.365129    0.881882      0.811321
# 40510 2019-08-30  3.163273 -1.671776  3.365129    0.881882      0.811321
# 40511 2019-08-30  3.163273 -1.671776  3.365129    0.881882      0.811321
#
#        최소 상대습도(pct)  평균 상대습도(pct)_x  강수 계속시간(hr)  일강수량(mm)  ...  \
# 0          0.405388        0.876138     0.549556  0.518922  ...
# 1          0.405388        0.876138     0.549556  0.518922  ...
# 2          0.405388        0.876138     0.549556  0.518922  ...
# 3          0.405388        0.876138     0.549556  0.518922  ...
# 4          0.405388        0.876138     0.549556  0.518922  ...
# ...             ...             ...          ...       ...  ...
# 40507      0.000000        0.816002    -1.290556 -0.894013  ...
# 40508      0.000000        0.816002    -1.290556 -0.894013  ...
# ...
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.9118805527687073, tolerance: 0.018051808699965477
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.01907353289425373, tolerance: 0.008968960493803024
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.11218265444040298, tolerance: 0.018051808699965477
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 44.84193801879883, tolerance: 0.008968960493803024
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 90.25531768798828, tolerance: 0.018051808699965477
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 44.841285705566406, tolerance: 0.008968960493803024
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 90.25408172607422, tolerance: 0.018051808699965477
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 44.84125900268555, tolerance: 0.008968960493803024
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 90.25397491455078, tolerance: 0.018051808699965477
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 19.780170440673828, tolerance: 0.008968960493803024
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.209850311279297, tolerance: 0.018051808699965477
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.9491603374481201, tolerance: 0.008968960493803024
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.3828918933868408, tolerance: 0.018051808699965477
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.012508584186434746, tolerance: 0.008968960493803024
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0440555065870285, tolerance: 0.018051808699965477
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 18.766868591308594, tolerance: 0.008968960493803024
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 13.97422981262207, tolerance: 0.018051808699965477
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10.80270004272461, tolerance: 0.008968960493803024
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5.255356788635254, tolerance: 0.018051808699965477
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.8263473510742188, tolerance: 0.008968960493803024
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.5827490091323853, tolerance: 0.018051808699965477
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.25659945607185364, tolerance: 0.008968960493803024
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 44.84203338623047, tolerance: 0.008968960493803024
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 90.25541687011719, tolerance: 0.018051808699965477
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 44.841392517089844, tolerance: 0.008968960493803024
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 90.25431060791016, tolerance: 0.018051808699965477
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 44.841339111328125, tolerance: 0.008968960493803024
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 90.25421905517578, tolerance: 0.018051808699965477
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 44.84263229370117, tolerance: 0.008968960493803024
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 90.255859375, tolerance: 0.018051808699965477
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 44.8416748046875, tolerance: 0.008968960493803024
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 90.25473022460938, tolerance: 0.018051808699965477
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 44.84163284301758, tolerance: 0.008968960493803024
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 90.25468444824219, tolerance: 0.018051808699965477
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 44.84302520751953, tolerance: 0.008968960493803024
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 90.2563705444336, tolerance: 0.018051808699965477
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 44.84280014038086, tolerance: 0.008968960493803024
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 90.25596618652344, tolerance: 0.018051808699965477
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 44.84280776977539, tolerance: 0.008968960493803024
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 90.2559814453125, tolerance: 0.018051808699965477
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 44.84434127807617, tolerance: 0.008968960493803024
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 90.25814056396484, tolerance: 0.018051808699965477
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 44.844337463378906, tolerance: 0.008968960493803024
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 90.25814056396484, tolerance: 0.018051808699965477
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 44.844337463378906, tolerance: 0.008968960493803024
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 90.25814056396484, tolerance: 0.018051808699965477
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 44.84474563598633, tolerance: 0.008968960493803024
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 90.2589340209961, tolerance: 0.018051808699965477
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 44.84474563598633, tolerance: 0.008968960493803024
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 90.25892639160156, tolerance: 0.018051808699965477
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 44.84474563598633, tolerance: 0.008968960493803024
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 90.25892639160156, tolerance: 0.018051808699965477
#   positive)
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 135.2763671875, tolerance: 0.02705630473792553
#   positive)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-93-f5b1c03436b1> in <module>
#       2 for X in result:
#       3     t_name = t_names[idx]
# ----> 4     grid_search_matrix(X, c=date_series, t_name=t_name, transformer = transformers[idx])
#       5     idx += 1
#
# <ipython-input-92-7f53f11f8a87> in grid_search_matrix(df, c, t_name, transformer)
#     173     r_test = inverser_transform(t_name, test_y.to_numpy().reshape(-1,1), transformer)
#     174     r_pred = inverser_transform(t_name, pred_y.reshape(-1,1), transformer)
# --> 175     return customized_rmse(r_test, r_pred)
#     176
#     177
#
# <ipython-input-92-7f53f11f8a87> in customized_rmse(y, y_pred)
#      92
#      93 def customized_rmse(y, y_pred):
# ---> 94     error = y - y_pred
#      95     def penalize(x):
#      96         if x > 0:
#
# TypeError: unsupported operand type(s) for -: 'NoneType' and 'NoneType'

# %%
a = list(map(functools.partial(grid_search_matrix, c=date_series), result))
a
