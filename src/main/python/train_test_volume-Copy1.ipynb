# %% [markdown]
# # SET TRAIN & TEST VOLUME

# %% [markdown]
# ### build dataset for one month

# %%
from util.build_dataset import build_master

dataset = build_master(bucket_name="production-bobsim", dataset="process_fmp", date="201908", pipe_data=False)
# Out:
# 2020-04-09 15:14:03:manage:<INFO> 1 files is loaded from public_data/open_data_raw_material_price/process/csv/201908.csv in s3 'production-bobsim'
# 2020-04-09 15:14:04:manage:<INFO> 1 files is loaded from public_data/open_data_terrestrial_weather/process/csv/201908.csv in s3 'production-bobsim'
# 2020-04-09 15:14:04:manage:<INFO> 1 files is loaded from public_data/open_data_marine_weather/process/csv/201908.csv in s3 'production-bobsim'

# %%
dataset07=build_master(bucket_name="production-bobsim", dataset="process_fmp", date="201907", pipe_data=False)
dataset06=build_master(bucket_name="production-bobsim", dataset="process_fmp", date="201906", pipe_data=False)
dataset05=build_master(bucket_name="production-bobsim", dataset="process_fmp", date="201905", pipe_data=False)
dataset04=build_master(bucket_name="production-bobsim", dataset="process_fmp", date="201904", pipe_data=False)
dataset03=build_master(bucket_name="production-bobsim", dataset="process_fmp", date="201903", pipe_data=False)
# Out:
# 2020-04-09 11:10:57:manage:<INFO> 1 files is loaded from public_data/open_data_raw_material_price/process/csv/201907.csv in s3 'production-bobsim'
# 2020-04-09 11:10:59:manage:<INFO> 1 files is loaded from public_data/open_data_terrestrial_weather/process/csv/201907.csv in s3 'production-bobsim'
# 2020-04-09 11:10:59:manage:<INFO> 1 files is loaded from public_data/open_data_marine_weather/process/csv/201907.csv in s3 'production-bobsim'
# 2020-04-09 11:10:59:main:<INFO> there is no raw material price data in process bucket
# 2020-04-09 11:11:14:manage:<INFO> 1 files is loaded from public_data/open_data_raw_material_price/origin/csv/201906.csv in s3 'production-bobsim'
# 2020-04-09 11:11:15:core:<INFO> missing values:
#  None
# 2020-04-09 11:11:15:manage:<INFO> success to save 'food_material_price_predict_model/image/origin_price_hist_201906.png' in s3 'production-bobsim'
# 2020-04-09 11:11:15:core:<INFO> price's mean: 1824.7551582563985, std: 2431.6750777886327
# 2020-04-09 11:11:16:manage:<INFO> success to save 'food_material_price_predict_model/image/stdized_price_hist_201906.png' in s3 'production-bobsim'
# 2020-04-09 11:11:16:manage:<INFO> success to save 'food_material_price_predict_model/price_(mean,std)_201906.pkl' in s3 'production-bobsim'
# 2020-04-09 11:11:20:manage:<INFO> success to save 'public_data/open_data_raw_material_price/process/csv/201906.csv' in s3 'production-bobsim'
# 2020-04-09 11:11:20:core:<INFO> success to process raw material price
# 2020-04-09 11:11:22:manage:<INFO> 1 files is loaded from public_data/open_data_raw_material_price/process/csv/201906.csv in s3 'production-bobsim'
# 2020-04-09 11:11:23:main:<INFO> there is no terrestrial weather data in process bucket
# 2020-04-09 11:11:44:manage:<INFO> 1 files is loaded from public_data/open_data_terrestrial_weather/origin/csv/2014-2020.csv in s3 'production-bobsim'
# 2020-04-09 11:11:44:manage:<INFO> success to save 'public_data/open_data_terrestrial_weather/process/csv/201906.csv' in s3 'production-bobsim'
# 2020-04-09 11:11:44:core:<INFO> success to process terrestrial weather
# 2020-04-09 11:11:44:manage:<INFO> 1 files is loaded from public_data/open_data_terrestrial_weather/process/csv/201906.csv in s3 'production-bobsim'
# 2020-04-09 11:11:45:main:<INFO> there is no marine weather data in process bucket
# 2020-04-09 11:11:49:manage:<INFO> 1 files is loaded from public_data/open_data_marine_weather/origin/csv/2014-2020.csv in s3 'production-bobsim'
# 2020-04-09 11:11:49:manage:<INFO> success to save 'public_data/open_data_marine_weather/process/csv/201906.csv' in s3 'production-bobsim'
# 2020-04-09 11:11:49:core:<INFO> success to process marine weather
# 2020-04-09 11:11:49:manage:<INFO> 1 files is loaded from public_data/open_data_marine_weather/process/csv/201906.csv in s3 'production-bobsim'
# 2020-04-09 11:11:49:main:<INFO> there is no raw material price data in process bucket
# 2020-04-09 11:12:13:manage:<INFO> 1 files is loaded from public_data/open_data_raw_material_price/origin/csv/201905.csv in s3 'production-bobsim'
# 2020-04-09 11:12:13:core:<INFO> missing values:
#  None
# 2020-04-09 11:12:14:manage:<INFO> success to save 'food_material_price_predict_model/image/origin_price_hist_201905.png' in s3 'production-bobsim'
# 2020-04-09 11:12:14:core:<INFO> price's mean: 1815.7257963237246, std: 2583.096393416287
# 2020-04-09 11:12:14:manage:<INFO> success to save 'food_material_price_predict_model/image/stdized_price_hist_201905.png' in s3 'production-bobsim'
# 2020-04-09 11:12:14:manage:<INFO> success to save 'food_material_price_predict_model/price_(mean,std)_201905.pkl' in s3 'production-bobsim'
# 2020-04-09 11:12:17:manage:<INFO> success to save 'public_data/open_data_raw_material_price/process/csv/201905.csv' in s3 'production-bobsim'
# 2020-04-09 11:12:17:core:<INFO> success to process raw material price
# 2020-04-09 11:12:20:manage:<INFO> 1 files is loaded from public_data/open_data_raw_material_price/process/csv/201905.csv in s3 'production-bobsim'
# 2020-04-09 11:12:20:main:<INFO> there is no terrestrial weather data in process bucket
# 2020-04-09 11:13:03:manage:<INFO> 1 files is loaded from public_data/open_data_terrestrial_weather/origin/csv/2014-2020.csv in s3 'production-bobsim'
# 2020-04-09 11:13:03:manage:<INFO> success to save 'public_data/open_data_terrestrial_weather/process/csv/201905.csv' in s3 'production-bobsim'
# 2020-04-09 11:13:03:core:<INFO> success to process terrestrial weather
# 2020-04-09 11:13:03:manage:<INFO> 1 files is loaded from public_data/open_data_terrestrial_weather/process/csv/201905.csv in s3 'production-bobsim'
# 2020-04-09 11:13:03:main:<INFO> there is no marine weather data in process bucket
# 2020-04-09 11:13:06:manage:<INFO> 1 files is loaded from public_data/open_data_marine_weather/origin/csv/2014-2020.csv in s3 'production-bobsim'
# 2020-04-09 11:13:06:manage:<INFO> success to save 'public_data/open_data_marine_weather/process/csv/201905.csv' in s3 'production-bobsim'
# 2020-04-09 11:13:06:core:<INFO> success to process marine weather
# 2020-04-09 11:13:06:manage:<INFO> 1 files is loaded from public_data/open_data_marine_weather/process/csv/201905.csv in s3 'production-bobsim'
# 2020-04-09 11:13:06:main:<INFO> there is no raw material price data in process bucket
# 2020-04-09 11:13:34:manage:<INFO> 1 files is loaded from public_data/open_data_raw_material_price/origin/csv/201904.csv in s3 'production-bobsim'
# 2020-04-09 11:13:34:core:<INFO> missing values:
#  None
# 2020-04-09 11:13:35:manage:<INFO> success to save 'food_material_price_predict_model/image/origin_price_hist_201904.png' in s3 'production-bobsim'
# 2020-04-09 11:13:35:core:<INFO> price's mean: 1825.7683676550262, std: 2741.218596521523
# 2020-04-09 11:13:35:manage:<INFO> success to save 'food_material_price_predict_model/image/stdized_price_hist_201904.png' in s3 'production-bobsim'
# 2020-04-09 11:13:35:manage:<INFO> success to save 'food_material_price_predict_model/price_(mean,std)_201904.pkl' in s3 'production-bobsim'
# 2020-04-09 11:13:44:manage:<INFO> success to save 'public_data/open_data_raw_material_price/process/csv/201904.csv' in s3 'production-bobsim'
# 2020-04-09 11:13:44:core:<INFO> success to process raw material price
# 2020-04-09 11:13:47:manage:<INFO> 1 files is loaded from public_data/open_data_raw_material_price/process/csv/201904.csv in s3 'production-bobsim'
# 2020-04-09 11:13:47:main:<INFO> there is no terrestrial weather data in process bucket
# 2020-04-09 11:14:08:manage:<INFO> 1 files is loaded from public_data/open_data_terrestrial_weather/origin/csv/2014-2020.csv in s3 'production-bobsim'
# 2020-04-09 11:14:09:manage:<INFO> success to save 'public_data/open_data_terrestrial_weather/process/csv/201904.csv' in s3 'production-bobsim'
# 2020-04-09 11:14:09:core:<INFO> success to process terrestrial weather
# 2020-04-09 11:14:09:manage:<INFO> 1 files is loaded from public_data/open_data_terrestrial_weather/process/csv/201904.csv in s3 'production-bobsim'
# 2020-04-09 11:14:09:main:<INFO> there is no marine weather data in process bucket
# 2020-04-09 11:14:11:manage:<INFO> 1 files is loaded from public_data/open_data_marine_weather/origin/csv/2014-2020.csv in s3 'production-bobsim'
# 2020-04-09 11:14:12:manage:<INFO> success to save 'public_data/open_data_marine_weather/process/csv/201904.csv' in s3 'production-bobsim'
# 2020-04-09 11:14:12:core:<INFO> success to process marine weather
# 2020-04-09 11:14:12:manage:<INFO> 1 files is loaded from public_data/open_data_marine_weather/process/csv/201904.csv in s3 'production-bobsim'
# 2020-04-09 11:14:12:main:<INFO> there is no raw material price data in process bucket
# 2020-04-09 11:14:29:manage:<INFO> 1 files is loaded from public_data/open_data_raw_material_price/origin/csv/201903.csv in s3 'production-bobsim'
# 2020-04-09 11:14:29:core:<INFO> missing values:
#  None
# 2020-04-09 11:14:30:manage:<INFO> success to save 'food_material_price_predict_model/image/origin_price_hist_201903.png' in s3 'production-bobsim'
# 2020-04-09 11:14:30:core:<INFO> price's mean: 1795.565108476736, std: 2607.0712217835066
# 2020-04-09 11:14:30:manage:<INFO> success to save 'food_material_price_predict_model/image/stdized_price_hist_201903.png' in s3 'production-bobsim'
# 2020-04-09 11:14:30:manage:<INFO> success to save 'food_material_price_predict_model/price_(mean,std)_201903.pkl' in s3 'production-bobsim'
# 2020-04-09 11:14:32:manage:<INFO> success to save 'public_data/open_data_raw_material_price/process/csv/201903.csv' in s3 'production-bobsim'
# 2020-04-09 11:14:32:core:<INFO> success to process raw material price
# 2020-04-09 11:14:33:manage:<INFO> 1 files is loaded from public_data/open_data_raw_material_price/process/csv/201903.csv in s3 'production-bobsim'
# 2020-04-09 11:14:34:main:<INFO> there is no terrestrial weather data in process bucket
# 2020-04-09 11:14:55:manage:<INFO> 1 files is loaded from public_data/open_data_terrestrial_weather/origin/csv/2014-2020.csv in s3 'production-bobsim'
# 2020-04-09 11:14:55:manage:<INFO> success to save 'public_data/open_data_terrestrial_weather/process/csv/201903.csv' in s3 'production-bobsim'
# 2020-04-09 11:14:55:core:<INFO> success to process terrestrial weather
# 2020-04-09 11:14:56:manage:<INFO> 1 files is loaded from public_data/open_data_terrestrial_weather/process/csv/201903.csv in s3 'production-bobsim'
# 2020-04-09 11:14:56:main:<INFO> there is no marine weather data in process bucket
# 2020-04-09 11:14:59:manage:<INFO> 1 files is loaded from public_data/open_data_marine_weather/origin/csv/2014-2020.csv in s3 'production-bobsim'
# 2020-04-09 11:15:00:manage:<INFO> success to save 'public_data/open_data_marine_weather/process/csv/201903.csv' in s3 'production-bobsim'
# 2020-04-09 11:15:00:core:<INFO> success to process marine weather
# 2020-04-09 11:15:00:manage:<INFO> 1 files is loaded from public_data/open_data_marine_weather/process/csv/201903.csv in s3 'production-bobsim'

# %%
dataset02=build_master(bucket_name="production-bobsim", dataset="process_fmp", date="201902", pipe_data=False)
dataset01=build_master(bucket_name="production-bobsim", dataset="process_fmp", date="201901", pipe_data=False)
dataset12_2018=build_master(bucket_name="production-bobsim", dataset="process_fmp", date="201812", pipe_data=False)
dataset11_2018=build_master(bucket_name="production-bobsim", dataset="process_fmp", date="201811", pipe_data=False)
dataset10_2018=build_master(bucket_name="production-bobsim", dataset="process_fmp", date="201810", pipe_data=False)
dataset09_2018=build_master(bucket_name="production-bobsim", dataset="process_fmp", date="201809", pipe_data=False)
dataset08_2018=build_master(bucket_name="production-bobsim", dataset="process_fmp", date="201908", pipe_data=False)
# Out:
# 2020-04-09 11:35:00:main:<INFO> there is no raw material price data in process bucket
# 2020-04-09 11:35:25:manage:<INFO> 1 files is loaded from public_data/open_data_raw_material_price/origin/csv/201902.csv in s3 'production-bobsim'
# 2020-04-09 11:35:25:core:<INFO> missing values:
#  None
# 2020-04-09 11:35:26:manage:<INFO> success to save 'food_material_price_predict_model/image/origin_price_hist_201902.png' in s3 'production-bobsim'
# 2020-04-09 11:35:26:core:<INFO> price's mean: 1845.8234708233792, std: 2918.28669094556
# 2020-04-09 11:35:26:manage:<INFO> success to save 'food_material_price_predict_model/image/stdized_price_hist_201902.png' in s3 'production-bobsim'
# 2020-04-09 11:35:26:manage:<INFO> success to save 'food_material_price_predict_model/price_(mean,std)_201902.pkl' in s3 'production-bobsim'
# 2020-04-09 11:35:30:manage:<INFO> success to save 'public_data/open_data_raw_material_price/process/csv/201902.csv' in s3 'production-bobsim'
# 2020-04-09 11:35:30:core:<INFO> success to process raw material price
# 2020-04-09 11:35:33:manage:<INFO> 1 files is loaded from public_data/open_data_raw_material_price/process/csv/201902.csv in s3 'production-bobsim'
# 2020-04-09 11:35:33:main:<INFO> there is no terrestrial weather data in process bucket
# 2020-04-09 11:36:07:manage:<INFO> 1 files is loaded from public_data/open_data_terrestrial_weather/origin/csv/2014-2020.csv in s3 'production-bobsim'
# 2020-04-09 11:36:09:manage:<INFO> success to save 'public_data/open_data_terrestrial_weather/process/csv/201902.csv' in s3 'production-bobsim'
# 2020-04-09 11:36:09:core:<INFO> success to process terrestrial weather
# 2020-04-09 11:36:09:manage:<INFO> 1 files is loaded from public_data/open_data_terrestrial_weather/process/csv/201902.csv in s3 'production-bobsim'
# 2020-04-09 11:36:10:main:<INFO> there is no marine weather data in process bucket
# 2020-04-09 11:36:12:manage:<INFO> 1 files is loaded from public_data/open_data_marine_weather/origin/csv/2014-2020.csv in s3 'production-bobsim'
# 2020-04-09 11:36:12:manage:<INFO> success to save 'public_data/open_data_marine_weather/process/csv/201902.csv' in s3 'production-bobsim'
# 2020-04-09 11:36:12:core:<INFO> success to process marine weather
# 2020-04-09 11:36:13:manage:<INFO> 1 files is loaded from public_data/open_data_marine_weather/process/csv/201902.csv in s3 'production-bobsim'
# 2020-04-09 11:36:13:main:<INFO> there is no raw material price data in process bucket
# 2020-04-09 11:36:53:manage:<INFO> 1 files is loaded from public_data/open_data_raw_material_price/origin/csv/201901.csv in s3 'production-bobsim'
# 2020-04-09 11:36:53:core:<INFO> missing values:
#  None
# 2020-04-09 11:36:53:manage:<INFO> success to save 'food_material_price_predict_model/image/origin_price_hist_201901.png' in s3 'production-bobsim'
# 2020-04-09 11:36:53:core:<INFO> price's mean: 1816.9343357068537, std: 2762.6534985659414
# 2020-04-09 11:36:54:manage:<INFO> success to save 'food_material_price_predict_model/image/stdized_price_hist_201901.png' in s3 'production-bobsim'
# 2020-04-09 11:36:54:manage:<INFO> success to save 'food_material_price_predict_model/price_(mean,std)_201901.pkl' in s3 'production-bobsim'
# 2020-04-09 11:36:56:manage:<INFO> success to save 'public_data/open_data_raw_material_price/process/csv/201901.csv' in s3 'production-bobsim'
# 2020-04-09 11:36:56:core:<INFO> success to process raw material price
# 2020-04-09 11:36:59:manage:<INFO> 1 files is loaded from public_data/open_data_raw_material_price/process/csv/201901.csv in s3 'production-bobsim'
# 2020-04-09 11:37:00:main:<INFO> there is no terrestrial weather data in process bucket
# 2020-04-09 11:37:27:manage:<INFO> 1 files is loaded from public_data/open_data_terrestrial_weather/origin/csv/2014-2020.csv in s3 'production-bobsim'
# 2020-04-09 11:37:28:manage:<INFO> success to save 'public_data/open_data_terrestrial_weather/process/csv/201901.csv' in s3 'production-bobsim'
# 2020-04-09 11:37:28:core:<INFO> success to process terrestrial weather
# 2020-04-09 11:37:30:manage:<INFO> 1 files is loaded from public_data/open_data_terrestrial_weather/process/csv/201901.csv in s3 'production-bobsim'
# 2020-04-09 11:37:30:main:<INFO> there is no marine weather data in process bucket
# 2020-04-09 11:37:33:manage:<INFO> 1 files is loaded from public_data/open_data_marine_weather/origin/csv/2014-2020.csv in s3 'production-bobsim'
# 2020-04-09 11:37:33:manage:<INFO> success to save 'public_data/open_data_marine_weather/process/csv/201901.csv' in s3 'production-bobsim'
# 2020-04-09 11:37:33:core:<INFO> success to process marine weather
# 2020-04-09 11:37:33:manage:<INFO> 1 files is loaded from public_data/open_data_marine_weather/process/csv/201901.csv in s3 'production-bobsim'
# 2020-04-09 11:37:34:main:<INFO> there is no raw material price data in process bucket
# 2020-04-09 11:38:15:manage:<INFO> 1 files is loaded from public_data/open_data_raw_material_price/origin/csv/201812.csv in s3 'production-bobsim'
# 2020-04-09 11:38:15:core:<INFO> missing values:
#  None
# 2020-04-09 11:38:15:manage:<INFO> success to save 'food_material_price_predict_model/image/origin_price_hist_201812.png' in s3 'production-bobsim'
# 2020-04-09 11:38:15:core:<INFO> price's mean: 1827.4435830482166, std: 2538.7424166245905
# 2020-04-09 11:38:16:manage:<INFO> success to save 'food_material_price_predict_model/image/stdized_price_hist_201812.png' in s3 'production-bobsim'
# 2020-04-09 11:38:16:manage:<INFO> success to save 'food_material_price_predict_model/price_(mean,std)_201812.pkl' in s3 'production-bobsim'
# 2020-04-09 11:38:19:manage:<INFO> success to save 'public_data/open_data_raw_material_price/process/csv/201812.csv' in s3 'production-bobsim'
# 2020-04-09 11:38:19:core:<INFO> success to process raw material price
# 2020-04-09 11:38:21:manage:<INFO> 1 files is loaded from public_data/open_data_raw_material_price/process/csv/201812.csv in s3 'production-bobsim'
# 2020-04-09 11:38:21:main:<INFO> there is no terrestrial weather data in process bucket
# 2020-04-09 11:38:46:manage:<INFO> 1 files is loaded from public_data/open_data_terrestrial_weather/origin/csv/2014-2020.csv in s3 'production-bobsim'
# 2020-04-09 11:38:46:manage:<INFO> success to save 'public_data/open_data_terrestrial_weather/process/csv/201812.csv' in s3 'production-bobsim'
# 2020-04-09 11:38:46:core:<INFO> success to process terrestrial weather
# 2020-04-09 11:38:47:manage:<INFO> 1 files is loaded from public_data/open_data_terrestrial_weather/process/csv/201812.csv in s3 'production-bobsim'
# 2020-04-09 11:38:47:main:<INFO> there is no marine weather data in process bucket
# 2020-04-09 11:38:52:manage:<INFO> 1 files is loaded from public_data/open_data_marine_weather/origin/csv/2014-2020.csv in s3 'production-bobsim'
# 2020-04-09 11:38:53:manage:<INFO> success to save 'public_data/open_data_marine_weather/process/csv/201812.csv' in s3 'production-bobsim'
# 2020-04-09 11:38:53:core:<INFO> success to process marine weather
# 2020-04-09 11:38:53:manage:<INFO> 1 files is loaded from public_data/open_data_marine_weather/process/csv/201812.csv in s3 'production-bobsim'
# 2020-04-09 11:38:53:main:<INFO> there is no raw material price data in process bucket
# 2020-04-09 11:39:14:manage:<INFO> 1 files is loaded from public_data/open_data_raw_material_price/origin/csv/201811.csv in s3 'production-bobsim'
# 2020-04-09 11:39:14:core:<INFO> missing values:
#  None
# 2020-04-09 11:39:15:manage:<INFO> success to save 'food_material_price_predict_model/image/origin_price_hist_201811.png' in s3 'production-bobsim'
# 2020-04-09 11:39:15:core:<INFO> price's mean: 1818.6568642211844, std: 2393.625103090817
# 2020-04-09 11:39:15:manage:<INFO> success to save 'food_material_price_predict_model/image/stdized_price_hist_201811.png' in s3 'production-bobsim'
# 2020-04-09 11:39:15:manage:<INFO> success to save 'food_material_price_predict_model/price_(mean,std)_201811.pkl' in s3 'production-bobsim'
# 2020-04-09 11:39:22:manage:<INFO> success to save 'public_data/open_data_raw_material_price/process/csv/201811.csv' in s3 'production-bobsim'
# 2020-04-09 11:39:22:core:<INFO> success to process raw material price
# 2020-04-09 11:39:24:manage:<INFO> 1 files is loaded from public_data/open_data_raw_material_price/process/csv/201811.csv in s3 'production-bobsim'
# 2020-04-09 11:39:25:main:<INFO> there is no terrestrial weather data in process bucket
# 2020-04-09 11:39:49:manage:<INFO> 1 files is loaded from public_data/open_data_terrestrial_weather/origin/csv/2014-2020.csv in s3 'production-bobsim'
# 2020-04-09 11:39:49:manage:<INFO> success to save 'public_data/open_data_terrestrial_weather/process/csv/201811.csv' in s3 'production-bobsim'
# 2020-04-09 11:39:49:core:<INFO> success to process terrestrial weather
# 2020-04-09 11:39:50:manage:<INFO> 1 files is loaded from public_data/open_data_terrestrial_weather/process/csv/201811.csv in s3 'production-bobsim'
# 2020-04-09 11:39:50:main:<INFO> there is no marine weather data in process bucket
# 2020-04-09 11:39:52:manage:<INFO> 1 files is loaded from public_data/open_data_marine_weather/origin/csv/2014-2020.csv in s3 'production-bobsim'
# 2020-04-09 11:39:52:manage:<INFO> success to save 'public_data/open_data_marine_weather/process/csv/201811.csv' in s3 'production-bobsim'
# 2020-04-09 11:39:52:core:<INFO> success to process marine weather
# 2020-04-09 11:39:53:manage:<INFO> 1 files is loaded from public_data/open_data_marine_weather/process/csv/201811.csv in s3 'production-bobsim'
# 2020-04-09 11:39:53:main:<INFO> there is no raw material price data in process bucket
# 2020-04-09 11:40:17:manage:<INFO> 1 files is loaded from public_data/open_data_raw_material_price/origin/csv/201810.csv in s3 'production-bobsim'
# 2020-04-09 11:40:17:core:<INFO> missing values:
#  None
# 2020-04-09 11:40:17:manage:<INFO> success to save 'food_material_price_predict_model/image/origin_price_hist_201810.png' in s3 'production-bobsim'
# 2020-04-09 11:40:17:core:<INFO> price's mean: 1964.2855607353706, std: 2710.4179371571313
# 2020-04-09 11:40:20:manage:<INFO> success to save 'food_material_price_predict_model/image/stdized_price_hist_201810.png' in s3 'production-bobsim'
# 2020-04-09 11:40:20:manage:<INFO> success to save 'food_material_price_predict_model/price_(mean,std)_201810.pkl' in s3 'production-bobsim'
# 2020-04-09 11:40:21:manage:<INFO> success to save 'public_data/open_data_raw_material_price/process/csv/201810.csv' in s3 'production-bobsim'
# 2020-04-09 11:40:21:core:<INFO> success to process raw material price
# 2020-04-09 11:40:24:manage:<INFO> 1 files is loaded from public_data/open_data_raw_material_price/process/csv/201810.csv in s3 'production-bobsim'
# 2020-04-09 11:40:24:main:<INFO> there is no terrestrial weather data in process bucket
# 2020-04-09 11:40:54:manage:<INFO> 1 files is loaded from public_data/open_data_terrestrial_weather/origin/csv/2014-2020.csv in s3 'production-bobsim'
# 2020-04-09 11:40:55:manage:<INFO> success to save 'public_data/open_data_terrestrial_weather/process/csv/201810.csv' in s3 'production-bobsim'
# 2020-04-09 11:40:55:core:<INFO> success to process terrestrial weather
# 2020-04-09 11:40:55:manage:<INFO> 1 files is loaded from public_data/open_data_terrestrial_weather/process/csv/201810.csv in s3 'production-bobsim'
# 2020-04-09 11:40:55:main:<INFO> there is no marine weather data in process bucket
# 2020-04-09 11:41:00:manage:<INFO> 1 files is loaded from public_data/open_data_marine_weather/origin/csv/2014-2020.csv in s3 'production-bobsim'
# 2020-04-09 11:41:00:manage:<INFO> success to save 'public_data/open_data_marine_weather/process/csv/201810.csv' in s3 'production-bobsim'
# 2020-04-09 11:41:00:core:<INFO> success to process marine weather
# 2020-04-09 11:41:00:manage:<INFO> 1 files is loaded from public_data/open_data_marine_weather/process/csv/201810.csv in s3 'production-bobsim'
# 2020-04-09 11:41:00:main:<INFO> there is no raw material price data in process bucket
# 2020-04-09 11:41:15:manage:<INFO> 1 files is loaded from public_data/open_data_raw_material_price/origin/csv/201809.csv in s3 'production-bobsim'
# 2020-04-09 11:41:15:core:<INFO> missing values:
#  None
# 2020-04-09 11:41:15:manage:<INFO> success to save 'food_material_price_predict_model/image/origin_price_hist_201809.png' in s3 'production-bobsim'
# 2020-04-09 11:41:15:core:<INFO> price's mean: 2138.170177717091, std: 3082.6169073081965
# 2020-04-09 11:41:16:manage:<INFO> success to save 'food_material_price_predict_model/image/stdized_price_hist_201809.png' in s3 'production-bobsim'
# 2020-04-09 11:41:16:manage:<INFO> success to save 'food_material_price_predict_model/price_(mean,std)_201809.pkl' in s3 'production-bobsim'
# 2020-04-09 11:41:18:manage:<INFO> success to save 'public_data/open_data_raw_material_price/process/csv/201809.csv' in s3 'production-bobsim'
# 2020-04-09 11:41:18:core:<INFO> success to process raw material price
# 2020-04-09 11:41:22:manage:<INFO> 1 files is loaded from public_data/open_data_raw_material_price/process/csv/201809.csv in s3 'production-bobsim'
# 2020-04-09 11:41:22:main:<INFO> there is no terrestrial weather data in process bucket
# 2020-04-09 11:41:50:manage:<INFO> 1 files is loaded from public_data/open_data_terrestrial_weather/origin/csv/2014-2020.csv in s3 'production-bobsim'
# 2020-04-09 11:41:50:manage:<INFO> success to save 'public_data/open_data_terrestrial_weather/process/csv/201809.csv' in s3 'production-bobsim'
# 2020-04-09 11:41:50:core:<INFO> success to process terrestrial weather
# 2020-04-09 11:41:50:manage:<INFO> 1 files is loaded from public_data/open_data_terrestrial_weather/process/csv/201809.csv in s3 'production-bobsim'
# 2020-04-09 11:41:51:main:<INFO> there is no marine weather data in process bucket
# 2020-04-09 11:41:53:manage:<INFO> 1 files is loaded from public_data/open_data_marine_weather/origin/csv/2014-2020.csv in s3 'production-bobsim'
# 2020-04-09 11:41:53:manage:<INFO> success to save 'public_data/open_data_marine_weather/process/csv/201809.csv' in s3 'production-bobsim'
# 2020-04-09 11:41:53:core:<INFO> success to process marine weather
# 2020-04-09 11:41:53:manage:<INFO> 1 files is loaded from public_data/open_data_marine_weather/process/csv/201809.csv in s3 'production-bobsim'
# 2020-04-09 11:41:55:manage:<INFO> 1 files is loaded from public_data/open_data_raw_material_price/process/csv/201908.csv in s3 'production-bobsim'
# 2020-04-09 11:41:56:manage:<INFO> 1 files is loaded from public_data/open_data_terrestrial_weather/process/csv/201908.csv in s3 'production-bobsim'
# 2020-04-09 11:41:56:manage:<INFO> 1 files is loaded from public_data/open_data_marine_weather/process/csv/201908.csv in s3 'production-bobsim'

# %%
from sklearn.linear_model import LinearRegression, ElasticNet
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from model.elastic_net import ElasticNetModel
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import functools
from util.visualize import draw_hist
from util.s3_manager.manage import S3Manager

def customized_rmse(y, y_pred):
    error = y - y_pred
    def penalize(x):
        if x > 0:
            # if y > y_pred, penalize 10%
            return x * 1.1
        else:
            return x
    X = np.vectorize(penalize)(error)
    return np.sqrt(np.square(X).mean())

def split_xy(df: pd.DataFrame):
    # print(df.조사일자.drop_duplicates())
    return df.drop(columns=["price", "date"]), df["price"]

def split_train_test(str_day, std_day, df: pd.DataFrame):
    train = df[(str_day <= df["date"].dt.date) & (df["date"].dt.date < std_day)]
    test = df[df["date"].dt.date >= std_day]
    return train, test


def get_score(train_size, test_size, df):
    time_series = df["date"].drop_duplicates().tolist()
    std_day = time_series[-1*test_size]
    str_day = time_series[-1*(test_size+train_size)]
    train, test = split_train_test(str_day=str_day, std_day=std_day, df=df)
    
    x_train, y_train = split_xy(train)
    x_test, y_test = split_xy(test)
    
    params = {'alpha': 0.0001, 'l1_ratio': 0.9, 'max_iter': 5}
    regr = ElasticNet(**params)
    regr.fit(x_train, y_train)
    y_pred = regr.predict(x_test)
    
    mean, std = S3Manager(bucket_name="production-bobsim").load_dump(
            key="food_material_price_predict_model/price_(mean,std).pkl"
        )
    
    metric = customized_rmse(y_test*std+mean, y_pred*std+mean)
    return metric



def rmse_by_train_size(df):
    test_size = 5
    train_sizes = range(1,16)
    score_list = list(map(functools.partial(get_score, test_size=test_size, df=df), train_sizes))
    ser = pd.Series(score_list, index=train_sizes)
    print(ser)
    
    plt.xlabel('train size')
    plt.ylabel('customized RMSE')
    ser.plot(kind="bar", ylim=(ser.min()-1,ser.max()+1), color="blue", title="test_size: {}".format(test_size))
    S3Manager(bucket_name="production-bobsim").save_plt_to_png(key="food_material_price_predict_model/image/rmse_by_train_size_201908.png")
    
    # draw_hist(ser, h_type="dist")
    # print("metric list for standard '{day}': {metrics}".format(day=standard_day, metrics=score_list))


def split_train_test2(std_day, end_day, df: pd.DataFrame):
    train = df[df["date"].dt.date <= std_day] 
    test = df[(std_day < df["date"].dt.date) & (df["date"].dt.date <= end_day )]
    return train, test

def get_score2(test_size, train_size, df):
    time_series = df["date"].drop_duplicates().tolist()
    std_day = time_series[train_size]
    end_day = time_series[test_size+train_size]
    print(end_day, std_day)
    train, test = split_train_test2(std_day=std_day, end_day=end_day, df=df)
    
    x_train, y_train = split_xy(train)
    x_test, y_test = split_xy(test)
    
    params = {'alpha': 0.0001, 'l1_ratio': 0.9, 'max_iter': 5}
    regr = ElasticNet(**params)
    regr.fit(x_train, y_train)
    y_pred = regr.predict(x_test)
    
    mean, std = S3Manager(bucket_name="production-bobsim").load_dump(
            key="food_material_price_predict_model/price_(mean,std).pkl"
        )
    
    metric = customized_rmse(y_test*std+mean, y_pred*std+mean)
    return metric


def rmse_by_test_size(df):
    test_sizes = range(1,10)
    train_size = 10
    score_list = list(map(functools.partial(get_score2, train_size=train_size, df=df), test_sizes))
    ser = pd.Series(score_list, index=test_sizes)
    print(ser)
    
    plt.xlabel('test size')
    plt.ylabel('customized RMSE')
    ser.plot(kind="bar", ylim=(ser.min()-1,ser.max()+1), color='red', title="train_size: {}".format(train_size))
    S3Manager(bucket_name="production-bobsim").save_plt_to_png(key="food_material_price_predict_model/image/rmse_by_test_size_201908.png")
    
def rmse_by_fix_size(df):
    test_size = 9
    train_size = 2
    score = get_score2(test_size=test_size , train_size=train_size , df=df)
    return score

    
def rmse_by_fix_size_10_5(df):
    test_size = range(1,10)
    train_size = 10
    score = get_score2(test_size=test_size , train_size=train_size , df=df)
    return score

# %%
rmse_by_train_size(dataset)
# Out:
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 454532279.76673275, tolerance: 1047342.304272725
#   positive)
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# <ipython-input-35-8cdb08ca42f6> in <module>
# ----> 1 rmse_by_train_size(dataset)
#
# <ipython-input-34-4ac73f5f3fdb> in rmse_by_train_size(df)
#      56     test_size = 5
#      57     train_sizes = range(1,16)
# ---> 58     score_list = list(map(functools.partial(get_score, test_size=test_size, df=df), train_sizes))
#      59     ser = pd.Series(score_list, index=train_sizes)
#      60     print(ser)
#
# <ipython-input-34-4ac73f5f3fdb> in get_score(train_size, test_size, df)
#      45
#      46     mean, std = S3Manager(bucket_name="production-bobsim").load_dump(
# ---> 47             key="food_material_price_predict_model/price_(mean,std).pkl"
#      48         )
#      49
#
# C:\BOBSIM\production-bobsim-python\src\main\python\util\s3_manager\manage.py in load_dump(self, key)
#      92     def load_dump(self, key: str):
#      93         with tempfile.TemporaryFile() as fp:
# ---> 94             self.s3_bucket.download_fileobj(Fileobj=fp, Key=key)
#      95             fp.seek(0)
#      96             x = load(fp)
#
# ~\Anaconda3\envs\BOBSIM\lib\site-packages\boto3\s3\inject.py in bucket_download_fileobj(self, Key, Fileobj, ExtraArgs, Callback, Config)
#     718     return self.meta.client.download_fileobj(
#     719         Bucket=self.name, Key=Key, Fileobj=Fileobj, ExtraArgs=ExtraArgs,
# --> 720         Callback=Callback, Config=Config)
#     721
#     722
#
# ~\Anaconda3\envs\BOBSIM\lib\site-packages\boto3\s3\inject.py in download_fileobj(self, Bucket, Key, Fileobj, ExtraArgs, Callback, Config)
#     676             bucket=Bucket, key=Key, fileobj=Fileobj,
#     677             extra_args=ExtraArgs, subscribers=subscribers)
# --> 678         return future.result()
#     679
#     680
#
# ~\Anaconda3\envs\BOBSIM\lib\site-packages\s3transfer\futures.py in result(self)
#     104             # however if a KeyboardInterrupt is raised we want want to exit
#     105             # out of this and propogate the exception.
# --> 106             return self._coordinator.result()
#     107         except KeyboardInterrupt as e:
#     108             self.cancel()
#
# ~\Anaconda3\envs\BOBSIM\lib\site-packages\s3transfer\futures.py in result(self)
#     263         # final result.
#     264         if self._exception:
# --> 265             raise self._exception
#     266         return self._result
#     267
#
# ~\Anaconda3\envs\BOBSIM\lib\site-packages\s3transfer\tasks.py in _main(self, transfer_future, **kwargs)
#     253             # Call the submit method to start submitting tasks to execute the
#     254             # transfer.
# --> 255             self._submit(transfer_future=transfer_future, **kwargs)
#     256         except BaseException as e:
#     257             # If there was an exception raised during the submission of task
#
# ~\Anaconda3\envs\BOBSIM\lib\site-packages\s3transfer\download.py in _submit(self, client, config, osutil, request_executor, io_executor, transfer_future, bandwidth_limiter)
#     341                 Bucket=transfer_future.meta.call_args.bucket,
#     342                 Key=transfer_future.meta.call_args.key,
# --> 343                 **transfer_future.meta.call_args.extra_args
#     344             )
#     345             transfer_future.meta.provide_transfer_size(
#
# ~\Anaconda3\envs\BOBSIM\lib\site-packages\botocore\client.py in _api_call(self, *args, **kwargs)
#     314                     "%s() only accepts keyword arguments." % py_operation_name)
#     315             # The "self" in this scope is referring to the BaseClient.
# --> 316             return self._make_api_call(operation_name, kwargs)
#     317
#     318         _api_call.__name__ = str(py_operation_name)
#
# ~\Anaconda3\envs\BOBSIM\lib\site-packages\botocore\client.py in _make_api_call(self, operation_name, api_params)
#     624             error_code = parsed_response.get("Error", {}).get("Code")
#     625             error_class = self.exceptions.from_code(error_code)
# --> 626             raise error_class(parsed_response, operation_name)
#     627         else:
#     628             return parsed_response
#
# ClientError: An error occurred (404) when calling the HeadObject operation: Not Found

# %%
rmse_by_fix_size(dataset)
# Out:
# 2019-08-19 00:00:00 2019-08-05 00:00:00
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1516276602.6848495, tolerance: 3067759.218572882
#   positive)
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# <ipython-input-33-11114b80a1ce> in <module>
# ----> 1 rmse_by_fix_size(dataset)
#
# <ipython-input-32-449afd672720> in rmse_by_fix_size(df)
#     112     test_size = 9
#     113     train_size = 2
# --> 114     score = get_score2(test_size=test_size , train_size=train_size , df=df)
#     115     return score
#     116
#
# <ipython-input-32-449afd672720> in get_score2(test_size, train_size, df)
#      90
#      91     mean, std = S3Manager(bucket_name="production-bobsim").load_dump(
# ---> 92             key="food_material_price_predict_model/price_(mean,std).pkl"
#      93         )
#      94
#
# C:\BOBSIM\production-bobsim-python\src\main\python\util\s3_manager\manage.py in load_dump(self, key)
#      92     def load_dump(self, key: str):
#      93         with tempfile.TemporaryFile() as fp:
# ---> 94             self.s3_bucket.download_fileobj(Fileobj=fp, Key=key)
#      95             fp.seek(0)
#      96             x = load(fp)
#
# ~\Anaconda3\envs\BOBSIM\lib\site-packages\boto3\s3\inject.py in bucket_download_fileobj(self, Key, Fileobj, ExtraArgs, Callback, Config)
#     718     return self.meta.client.download_fileobj(
#     719         Bucket=self.name, Key=Key, Fileobj=Fileobj, ExtraArgs=ExtraArgs,
# --> 720         Callback=Callback, Config=Config)
#     721
#     722
#
# ~\Anaconda3\envs\BOBSIM\lib\site-packages\boto3\s3\inject.py in download_fileobj(self, Bucket, Key, Fileobj, ExtraArgs, Callback, Config)
#     676             bucket=Bucket, key=Key, fileobj=Fileobj,
#     677             extra_args=ExtraArgs, subscribers=subscribers)
# --> 678         return future.result()
#     679
#     680
#
# ~\Anaconda3\envs\BOBSIM\lib\site-packages\s3transfer\futures.py in result(self)
#     104             # however if a KeyboardInterrupt is raised we want want to exit
#     105             # out of this and propogate the exception.
# --> 106             return self._coordinator.result()
#     107         except KeyboardInterrupt as e:
#     108             self.cancel()
#
# ~\Anaconda3\envs\BOBSIM\lib\site-packages\s3transfer\futures.py in result(self)
#     263         # final result.
#     264         if self._exception:
# --> 265             raise self._exception
#     266         return self._result
#     267
#
# ~\Anaconda3\envs\BOBSIM\lib\site-packages\s3transfer\tasks.py in _main(self, transfer_future, **kwargs)
#     253             # Call the submit method to start submitting tasks to execute the
#     254             # transfer.
# --> 255             self._submit(transfer_future=transfer_future, **kwargs)
#     256         except BaseException as e:
#     257             # If there was an exception raised during the submission of task
#
# ~\Anaconda3\envs\BOBSIM\lib\site-packages\s3transfer\download.py in _submit(self, client, config, osutil, request_executor, io_executor, transfer_future, bandwidth_limiter)
#     341                 Bucket=transfer_future.meta.call_args.bucket,
#     342                 Key=transfer_future.meta.call_args.key,
# --> 343                 **transfer_future.meta.call_args.extra_args
#     344             )
#     345             transfer_future.meta.provide_transfer_size(
#
# ~\Anaconda3\envs\BOBSIM\lib\site-packages\botocore\client.py in _api_call(self, *args, **kwargs)
#     314                     "%s() only accepts keyword arguments." % py_operation_name)
#     315             # The "self" in this scope is referring to the BaseClient.
# --> 316             return self._make_api_call(operation_name, kwargs)
#     317
#     318         _api_call.__name__ = str(py_operation_name)
#
# ~\Anaconda3\envs\BOBSIM\lib\site-packages\botocore\client.py in _make_api_call(self, operation_name, api_params)
#     624             error_code = parsed_response.get("Error", {}).get("Code")
#     625             error_class = self.exceptions.from_code(error_code)
# --> 626             raise error_class(parsed_response, operation_name)
#     627         else:
#     628             return parsed_response
#
# ClientError: An error occurred (404) when calling the HeadObject operation: Not Found

# %% [markdown]
# ### fix volume : train=2 , test=9

# %%
score_list=list(map(rmse_by_fix_size,[
    dataset,dataset07,dataset06,dataset05,dataset04,dataset03,dataset02,dataset01,dataset12_2018,
    dataset11_2018,dataset10_2018,dataset09_2018,dataset08_2018
]))

ser=pd.Series(score_list, index=[8,7,6,5,4,3,2,1,12,11,10,9,8])

plt.xlabel('month')
plt.ylabel('customized RMSE')
ser.plot(kind="bar")
S3Manager(bucket_name="production-bobsim").save_plt_to_png(key="food_material_price_predict_model/image/rmse_by_month_2019_2018.png")
# Out:
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 77.38376714962152, tolerance: 0.479896611929776
#   positive)
# 2019-08-19 00:00:00 2019-08-05 00:00:00
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 26.38761396701034, tolerance: 0.4297690758534329
#   positive)
# 2019-07-17 00:00:00 2019-07-03 00:00:00
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 27.0591528142713, tolerance: 0.4751137173225842
#   positive)
# 2019-06-19 00:00:00 2019-06-05 00:00:00
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 29.24022707309787, tolerance: 0.5110337272150389
#   positive)
# 2019-05-20 00:00:00 2019-05-07 00:00:00
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 43.350448612450734, tolerance: 0.49788626105540684
#   positive)
# 2019-04-16 00:00:00 2019-04-03 00:00:00
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 45.93144430869245, tolerance: 0.4495048456151662
#   positive)
# 2019-03-19 00:00:00 2019-03-06 00:00:00
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 34.16672369071255, tolerance: 0.5038303136393902
#   positive)
# 2019-02-21 00:00:00 2019-02-08 00:00:00
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 35.969339492801, tolerance: 0.4475041723451503
#   positive)
# 2019-01-17 00:00:00 2019-01-04 00:00:00
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 70.66569119126703, tolerance: 0.4094793321496922
#   positive)
# 2018-12-20 00:00:00 2018-12-05 00:00:00
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 63.525865584075234, tolerance: 0.5126688976920716
#   positive)
# 2018-11-19 00:00:00 2018-11-05 00:00:00
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 166.3811771937876, tolerance: 0.5131891636177308
#   positive)
# 2018-10-18 00:00:00 2018-10-04 00:00:00
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 79.33387902868512, tolerance: 0.4200310858590848
#   positive)
# 2018-09-18 00:00:00 2018-09-05 00:00:00
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 77.38376714962152, tolerance: 0.479896611929776
#   positive)
# 2019-08-19 00:00:00 2019-08-05 00:00:00
# 2020-04-09 11:48:10:manage:<INFO> success to save 'food_material_price_predict_model/image/rmse_by_month_2019_2018.png' in s3 'production-bobsim'

# %% [markdown]
# ### fix volume : train=10 , test=5

# %%
score_list=list(map(rmse_by_fix_size_10_5,[
    dataset,dataset07,dataset06,dataset05,dataset04,dataset03,dataset02,dataset01,dataset12_2018,
    dataset11_2018,dataset10_2018,dataset09_2018,dataset08_2018
]))

ser=pd.Series(score_list, index=[8,7,6,5,4,3,2,1,12,11,10,9,8])

plt.xlabel('month')
plt.ylabel('customized RMSE')
ser.plot(kind="bar")
S3Manager(bucket_name="production-bobsim").save_plt_to_png(key="food_material_price_predict_model/image/rmse_by_month_2019_2018.png")
# Out:
# 2019-08-23 00:00:00 2019-08-16 00:00:00
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 650.8833068490022, tolerance: 1.7766161157018776
#   positive)
# 2019-07-23 00:00:00 2019-07-16 00:00:00
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 196.14070147556185, tolerance: 1.6717100839853236
#   positive)
# 2019-06-25 00:00:00 2019-06-18 00:00:00
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 257.556803739295, tolerance: 1.693539370343987
#   positive)
# 2019-05-24 00:00:00 2019-05-17 00:00:00
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 323.75385934950026, tolerance: 1.806020697358359
#   positive)
# 2019-04-22 00:00:00 2019-04-15 00:00:00
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 139.17150488755607, tolerance: 1.8278880276603167
#   positive)
# 2019-03-25 00:00:00 2019-03-18 00:00:00
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 378.13098058223096, tolerance: 1.7033049776010272
#   positive)
# 2019-02-27 00:00:00 2019-02-20 00:00:00
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 164.45127778879794, tolerance: 1.8423198323343168
#   positive)
# 2019-01-23 00:00:00 2019-01-16 00:00:00
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 341.57013094391993, tolerance: 1.6705361620216452
#   positive)
# 2018-12-27 00:00:00 2018-12-19 00:00:00
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 384.1828255786313, tolerance: 1.572335883723654
#   positive)
# 2018-11-23 00:00:00 2018-11-16 00:00:00
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 508.2705125273232, tolerance: 1.7871399569130402
#   positive)
# 2018-10-24 00:00:00 2018-10-17 00:00:00
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 842.9379082561376, tolerance: 1.7916422598651476
#   positive)
# 2018-09-27 00:00:00 2018-09-17 00:00:00
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 743.6819006676648, tolerance: 1.6825285955654128
#   positive)
# 2019-08-23 00:00:00 2019-08-16 00:00:00
# C:\Users\park\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 650.8833068490022, tolerance: 1.7766161157018776
#   positive)
# 2020-04-09 12:00:02:manage:<INFO> success to save 'food_material_price_predict_model/image/rmse_by_month_2019_2018.png' in s3 'production-bobsim'

# %%
from sklearn.linear_model import ElasticNet

en = ElasticNet(alpha=0, l1_ratio=0.0, max_iter=5)
en.fit(train_x, train_y)
pred = en.predict(test_x)
model_pipeline.customized_rmse(test_y, pred)
### fix volume : train=2 , test=9
# Out:
# C:\Users\jinho\Anaconda3\envs\BOBSIM\lib\site-packages\ipykernel_launcher.py:4: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   after removing the cwd from sys.path.
# C:\Users\jinho\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   positive)
# C:\Users\jinho\Anaconda3\envs\BOBSIM\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2960803954.906143, tolerance: 16733436.770004129
#   positive)
# 568.4727293334064
